// %% [markdown]
// Ejercicio 1 — Funciones puras para cálculos matemáticos

// %%
def areaCirculo(radio: Double): Double =
 scala.math.Pi * radio * radio

def areaRectangulo(base: Double, altura: Double): Double =
  base * altura

def areaTrapecio(baseMayor: Double, baseMenor: Double, altura: Double): Double =
  ((baseMayor + baseMenor) / 2) * altura

def celsiusAFahrenheit(celsius: Double): Double =
  (celsius * 9.0 / 5.0) + 32

def esDivisible(numero: Int, divisor: Int): Boolean =
  numero % divisor == 0
// Out:
// defined function areaCirculo
// defined function areaRectangulo
// defined function areaTrapecio
// defined function celsiusAFahrenheit
// defined function esDivisible

// %%
println("=== Áreas ===")
println(f"Círculo r=5:          ${areaCirculo(5)}%.2f")
println(f"Rectángulo 8×3:       ${areaRectangulo(8, 3)}%.2f")
println(f"Trapecio (10,6) h=4:  ${areaTrapecio(10, 6, 4)}%.2f")
// Out:
// === Áreas ===
// Círculo r=5:          78.54
// Rectángulo 8×3:       24.00
// Trapecio (10,6) h=4:  32.00

// %%
println("=== Conversión de temperatura ===")
for (temp <- List(0.0, 20.0, 37.0, 100.0)) {
  println(f"  $temp%.1f°C → ${celsiusAFahrenheit(temp)}%.1f°F")
}
// Out:
// === Conversión de temperatura ===
//   0.0°C → 32.0°F
//   20.0°C → 68.0°F
//   37.0°C → 98.6°F
//   100.0°C → 212.0°F

// %%
val numero = 42
println(s"=== Divisibilidad de $numero ===")
for (d <- List(2, 3, 5, 7)) {
  val resultado = if (esDivisible(numero, d)) "sí" else "no"
  println(s"  ¿$numero es divisible entre $d? $resultado")
}
// Out:
// === Divisibilidad de 42 ===
//   ¿42 es divisible entre 2? sí
//   ¿42 es divisible entre 3? sí
//   ¿42 es divisible entre 5? no
//   ¿42 es divisible entre 7? sí
// numero: Int = 42

// %% [markdown]
// Ejercicio 2 — map, filter y reduce sobre listas

// %%
val alumnos = List(
  ("Ana",    8.5),
  ("Luis",   4.2),
  ("Marta",  9.1),
  ("Carlos", 5.8),
  ("Elena",  3.9),
  ("Pedro",  7.4)
)

// Extraer solo los nombres
val nombres = alumnos.map(_._1)
println(s"Alumnos: ${nombres.mkString(", ")}")

// Extraer solo las notas (la última expresión la muestra Almond automáticamente)
val notas = alumnos.map(_._2)
notas
// Out:
// Alumnos: Ana, Luis, Marta, Carlos, Elena, Pedro
// alumnos: List[(String, Double)] = List(
//   ("Ana", 8.5),
//   ("Luis", 4.2),
//   ("Marta", 9.1),
//   ("Carlos", 5.8),
//   ("Elena", 3.9),
//   ("Pedro", 7.4)
// )
// nombres: List[String] = List("Ana", "Luis", "Marta", "Carlos", "Elena", "Pedro")
// notas: List[Double] = List(8.5, 4.2, 9.1, 5.8, 3.9, 7.4)
// res6_4: List[Double] = List(8.5, 4.2, 9.1, 5.8, 3.9, 7.4)

// %%
val alumnos = List(
  ("Ana",    8.5),
  ("Luis",   4.2),
  ("Marta",  9.1),
  ("Carlos", 5.8),
  ("Elena",  3.9),
  ("Pedro",  7.4)
)
// Out:
// alumnos: List[(String, Double)] = List(
//   ("Ana", 8.5),
//   ("Luis", 4.2),
//   ("Marta", 9.1),
//   ("Carlos", 5.8),
//   ("Elena", 3.9),
//   ("Pedro", 7.4)
// )

// %%
val nombres = alumnos.map(_._1)
// List("Ana", "Luis", "Marta", "Carlos", "Elena", "Pedro")
// Out:
// nombres: List[String] = List("Ana", "Luis", "Marta", "Carlos", "Elena", "Pedro")

// %%
println(s"Alumnos: ${nombres.mkString(", ")}")
// Out:
// Alumnos: Ana, Luis, Marta, Carlos, Elena, Pedro

// %%
val notas = alumnos.map(_._2)
// List(8.5, 4.2, 9.1, 5.8, 3.9, 7.4)
// Out:
// notas: List[Double] = List(8.5, 4.2, 9.1, 5.8, 3.9, 7.4)

// %%
val aprobados = alumnos.filter(_._2 >= 5.0)
println(s"Aprobados (${aprobados.length}):")
aprobados.foreach { case (nombre, nota) =>
  println(f"  $nombre%-8s → $nota%.1f")
}

val suspensos = alumnos.filter(_._2 < 5.0)
println(s"\nSuspensos (${suspensos.length}):")
suspensos.foreach { case (nombre, nota) =>
  println(f"  $nombre%-8s → $nota%.1f")
}
// Out:
// Aprobados (4):
//   Ana      → 8.5
//   Marta    → 9.1
//   Carlos   → 5.8
//   Pedro    → 7.4
//
// Suspensos (2):
//   Luis     → 4.2
//   Elena    → 3.9
// aprobados: List[(String, Double)] = List(
//   ("Ana", 8.5),
//   ("Marta", 9.1),
//   ("Carlos", 5.8),
//   ("Pedro", 7.4)
// )
// suspensos: List[(String, Double)] = List(("Luis", 4.2), ("Elena", 3.9))

// %%
val notaMaxima = notas.reduce((a, b) => if (a > b) a else b)
val notaMinima = notas.reduce((a, b) => if (a < b) a else b)
val notaMedia  = notas.reduce(_ + _) / notas.length

println("=== Estadísticas ===")
println(f"  Nota máxima: $notaMaxima%.1f")
println(f"  Nota mínima: $notaMinima%.1f")
println(f"  Nota media:  $notaMedia%.2f")
// Out:
// === Estadísticas ===
//   Nota máxima: 9.1
//   Nota mínima: 3.9
//   Nota media:  6.48
// notaMaxima: Double = 9.1
// notaMinima: Double = 3.9
// notaMedia: Double = 6.483333333333333

// %%
def limpiar(texto: String): String =
  texto.trim

def capitalizar(texto: String): String =
  texto.split(" ").map(_.capitalize).mkString(" ")

def contarPalabras(texto: String): Int =
  texto.trim.split("\\s+").length
// Out:
// defined function limpiar
// defined function capitalizar
// defined function contarPalabras

// %%
val frases = List(
  "  scala es un lenguaje poderoso  ",
  "big data transforma las empresas",
  "apache spark usa scala",
  "  la programación funcional es elegante  ",
  "java y scala comparten la jvm"
)

println("=== Frases originales ===")
frases.foreach(f => println(s"  '$f'"))
// Out:
// === Frases originales ===
//   '  scala es un lenguaje poderoso  '
//   'big data transforma las empresas'
//   'apache spark usa scala'
//   '  la programación funcional es elegante  '
//   'java y scala comparten la jvm'
// frases: List[String] = List(
//   "  scala es un lenguaje poderoso  ",
//   "big data transforma las empresas",
//   "apache spark usa scala",
//   "  la programación funcional es elegante  ",
//   "java y scala comparten la jvm"
// )

// %%
val frasesProcesadas = frases
  .map(limpiar)
  .map(capitalizar)

println("=== Frases procesadas ===")
frasesProcesadas.foreach(f => println(s"  $f"))
// Out:
// === Frases procesadas ===
//   Scala Es Un Lenguaje Poderoso
//   Big Data Transforma Las Empresas
//   Apache Spark Usa Scala
//   La Programación Funcional Es Elegante
//   Java Y Scala Comparten La Jvm
// frasesProcesadas: List[String] = List(
//   "Scala Es Un Lenguaje Poderoso",
//   "Big Data Transforma Las Empresas",
//   "Apache Spark Usa Scala",
//   "La Programación Funcional Es Elegante",
//   "Java Y Scala Comparten La Jvm"
// )

// %%
val frasesLargas = frasesProcesadas.filter(f => contarPalabras(f) > 4)

println("=== Frases con más de 4 palabras ===")
frasesLargas.foreach(f => println(s"  $f"))
// Out:
// === Frases con más de 4 palabras ===
//   Scala Es Un Lenguaje Poderoso
//   Big Data Transforma Las Empresas
//   La Programación Funcional Es Elegante
//   Java Y Scala Comparten La Jvm
// frasesLargas: List[String] = List(
//   "Scala Es Un Lenguaje Poderoso",
//   "Big Data Transforma Las Empresas",
//   "La Programación Funcional Es Elegante",
//   "Java Y Scala Comparten La Jvm"
// )

// %%
val totalPalabras = frasesProcesadas.map(contarPalabras).reduce(_ + _)

println("=== Resumen ===")
println(s"  Frases totales:           ${frases.length}")
println(s"  Frases largas (>4 pal.):  ${frasesLargas.length}")
println(s"  Total de palabras:        $totalPalabras")
println(f"  Media palabras/frase:     ${totalPalabras.toDouble / frases.length}%.1f")
// Out:
// === Resumen ===
//   Frases totales:           5
//   Frases largas (>4 pal.):  4
//   Total de palabras:        25
//   Media palabras/frase:     5.0
// totalPalabras: Int = 25
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %% [markdown]
//  Ejercicio P1
//  Define una función calcularPerimetro que reciba la base y la altura de un rectángulo y devuelva su perímetro.
//  base=6, altura=4   → 20
//  base=10, altura=3  → 26

// %%
def calcularPerimetro (base: Double, altura: Double): Double =
  2 * (base + altura)

println("=== Resultado ===")
println(f"Perimetro b=6, h=4:          ${calcularPerimetro(6, 4)}%.2f")
println(f"Perimetro b=10, h=3:         ${calcularPerimetro(10, 3)}%.2f")
// Out:
// === Resultado ===
// Perimetro b=6, h=4:          20.00
// Perimetro b=10, h=3:         26.00
// defined function calcularPerimetro
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %% [markdown]
// Ejercicio P2
// Define una función esMayorDeEdad que reciba una edad (Int) y devuelva un Boolean indicando si la persona es mayor de edad (18 o más).
//
// Pruébala con:
//
// esMayorDeEdad(17)  → false
// esMayorDeEdad(18)  → true
// esMayorDeEdad(25)  → true

// %%
def esMayorDeEdad(edad: Int): Boolean =
  edad >= 18

println("=== Resultado ===")
println(s"  ¿17 es mayor de edad? -> ${esMayorDeEdad(17)}")
println(s"  ¿18 es mayor de edad? -> ${esMayorDeEdad(18)}")
println(s"  ¿25 es mayor de edad? -> ${esMayorDeEdad(25)}")
// Out:
// === Resultado ===
//   ¿17 es mayor de edad? -> false
//   ¿18 es mayor de edad? -> true
//   ¿25 es mayor de edad? -> true
// defined function esMayorDeEdad

// %% [markdown]
// Define una función euroADolar que convierta una cantidad en euros a dólares usando el tipo de cambio 1.08.
//
// Pruébala con:
//
// euroADolar(100.0)  → 108.0
// euroADolar(250.0)  → 270.0

// %%
def euroADolar(euro: Double): Double =
  euro * 1.08

println("=== Resultado ===")
println(s"  100 euros es igual a -> ${euroADolar(100)} dólares")
println(s"  250 euros es igual a -> ${euroADolar(250)} dólares")
// Out:
// === Resultado ===
//   100 euros es igual a -> 108.0 dólares
//   250 euros es igual a -> 270.0 dólares
// defined function euroADolar
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %% [markdown]
// Define una función saludo con dos parámetros:
//
// nombre: String — obligatorio
// idioma: String — con valor por defecto "es"
// Si idioma es "es" devuelve "Hola, <nombre>!", si es "en" devuelve "Hello, <nombre>!".
//
// saludo("Ana")           → "Hola, Ana!"
// saludo("Ana", "en")     → "Hello, Ana!"

// %%
def saludo(nombre: String, idioma: String = "es"): String =
  if (idioma == "es") {
    s"Hola, $nombre!"
  } else {
    s"Hello, $nombre!"
  }
println("=== Resultado ===")
println(s"  Saludo en español: ${saludo("Ana")}")
println(s"  Saludo en inglés:  ${saludo("Ana", "en")}")
// Out:
// === Resultado ===
//   Saludo en español: Hola, Ana!
//   Saludo en inglés:  Hello, Ana!
// defined function saludo

// %% [markdown]
// 🔹 Ejercicio P5
// Dada la siguiente lista:
//
// val temperaturas = List(18.0, 22.5, 30.1, 15.3, 27.8)
// Usa map para convertir todas las temperaturas de Celsius a Fahrenheit con la fórmula (c * 9.0 / 5.0) + 32.

// %%
val temperaturas = List(18.0, 22.5, 30.1, 15.3, 27.8)
val temperaturasF = temperaturas.map(_ * 9.0 / 5.0 + 32)
println("=== Temperaturas en Fahrenheit ===")
println(temperaturasF)
// Out:
// === Temperaturas en Fahrenheit ===
// List(64.4, 72.5, 86.18, 59.540000000000006, 82.04)
// temperaturas: List[Double] = List(18.0, 22.5, 30.1, 15.3, 27.8)
// temperaturasF: List[Double] = List(64.4, 72.5, 86.18, 59.540000000000006, 82.04)
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %% [markdown]
// Dada la siguiente lista:
//
// val palabras = List("scala", "spark", "hadoop", "kafka", "flink")
// Usa filter para quedarte solo con las palabras que tengan más de 5 letras.

// %%
val palabras = List("scala", "spark", "hadoop", "kafka", "flink")
val palabrasMayores5 = palabras.filter(_.length > 5)
// Out:
// palabras: List[String] = List("scala", "spark", "hadoop", "kafka", "flink")
// palabrasMayores5: List[String] = List("hadoop")
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %% [markdown]
// Dada la siguiente lista:
//
// val numeros = List(3, 7, 2, 9, 4, 6)
// Usa reduce para encontrar el número mínimo de la lista.

// %%
val numeros = List(3, 7, 2, 9, 4, 6)
val minimo  = numeros.reduce((a, b) => if (a < b) a else b)
// Out:
// numeros: List[Int] = List(3, 7, 2, 9, 4, 6)
// minimo: Int = 2
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %% [markdown]
// Ejercicio P8
// Implementa la misma función de tres formas distintas.
//
// La función recibe un número Int y devuelve ese número multiplicado por sí mismo (al cuadrado).
//
// // 1. Con def
// ???
//
// // 2. Anónima pura — se ejecuta directamente con el valor 7
// ???
//
// // 3. Guardada en val
// ???

// %%
//funcion 1
def numeroAlCuadrado(n: Int): Int =
  n * n

println(s"Con función, el número 7 al cuadrado es ${numeroAlCuadrado(7)}")

//funcion 2
println(s"Con función anónima, el número 7 al cuadrado es ${((n: Int) => n * n)(7)}")

//funcion 3
val numeroAlCuadrado2 = (n: Int) => n * n
println(s"Con función val, el número 7 al cuadrado es ${numeroAlCuadrado2(7)}")
// Out:
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %% [markdown]
// Ejercicio P9
// Implementa la misma función de tres formas distintas.
//
// La función recibe dos String y los concatena separados por un espacio.
//
// // 1. Con def
// ???
//
// // 2. Anónima pura — pruébala con ("Big", "Data")
// ???
//
// // 3. Guardada en val
// ???
//
// Salida esperada para ("Big", "Data"):
// "Big Data"

// %%
//funcion 1
def concatenar(a: String, b: String): String =
  a + " " + b

println(s"Concatenar 'Big' y 'Data' con función: ${concatenar("Big", "Data")}")

//funcion 2
println(s"Concatenar 'Big' y 'Data' con función anónima: ${((a: String, b: String) => a + " " + b)("Big", "Data")}")

//funcion 3
val concatenar2 = (a: String, b: String) => a + " " + b
println(s"Concatenar 'Big' y 'Data' con función val: ${concatenar2("Big", "Data")}")
// Out:
// Concatenar 'Big' y 'Data' con función: Big Data
// Concatenar 'Big' y 'Data' con función anónima: Big Data
// Concatenar 'Big' y 'Data' con función val: Big Data
// defined function concatenar
// concatenar2: (String, String) => String = ammonite.$sess.cmd1$Helper$$Lambda$2138/635799505@1a4e7e67
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %% [markdown]
// Ejercicio P10
// Dada la siguiente lista de tuplas (producto, precio):
//
// val productos = List(
//   ("Teclado",  45.0),
//   ("Ratón",    20.0),
//   ("Monitor", 180.0),
//   ("Webcam",   35.0),
//   ("Auriculares", 60.0)
// )
// Extrae solo los nombres de los productos con un precio superior a 40.0.
//
// List(Teclado, Monitor, Auriculares)

// %%
val productos = List(
  ("Teclado",  45.0),
  ("Ratón",    20.0),
  ("Monitor", 180.0),
  ("Webcam",   35.0),
  ("Auriculares", 60.0)
)

val superior = productos.filter(_._2 > 40.0)
println("=== Productos con precio superior a 40.0 ===")
println(s"  ${superior.map(_._1).mkString(", ")}")
println(superior.map(_._1))
// Out:
// === Productos con precio superior a 40.0 ===
//   Teclado, Monitor, Auriculares
// List(Teclado, Monitor, Auriculares)
// productos: List[(String, Double)] = List(
//   ("Teclado", 45.0),
//   ("Ratón", 20.0),
//   ("Monitor", 180.0),
//   ("Webcam", 35.0),
//   ("Auriculares", 60.0)
// )
// superior: List[(String, Double)] = List(
//   ("Teclado", 45.0),
//   ("Monitor", 180.0),
//   ("Auriculares", 60.0)
// )

// %% [markdown]
// Ejercicio P11
// Usando la misma lista de productos del ejercicio anterior:
//
// Filtra los productos con precio mayor de 30.0
// Aplica un descuento del 10% a cada precio (precio * 0.90)
// Suma todos los precios resultantes con reduce
// Salida esperada:
//
// 270.0

// %%
val productos = List(
  ("Teclado",  45.0),
  ("Ratón",    20.0),
  ("Monitor", 180.0),
  ("Webcam",   35.0),
  ("Auriculares", 60.0)
)

val superior = productos.filter(_._2 > 30.0)
val superiorDescuento = superior.map (_._2 * 0.9)
println(superiorDescuento)
val resultadoSuperiorDescuento = superiorDescuento.reduce(_ + _)
println(f"=== Suma de precios con descuento (10 por ciento) para productos mayores a 30.0 ===")
println(f"  Total : $resultadoSuperiorDescuento%.2f")
// Out:
// List(40.5, 162.0, 31.5, 54.0)
// === Suma de precios con descuento (10 por ciento) para productos mayores a 30.0 ===
//   Total : 288.00
// productos: List[(String, Double)] = List(
//   ("Teclado", 45.0),
//   ("Ratón", 20.0),
//   ("Monitor", 180.0),
//   ("Webcam", 35.0),
//   ("Auriculares", 60.0)
// )
// superior: List[(String, Double)] = List(
//   ("Teclado", 45.0),
//   ("Monitor", 180.0),
//   ("Webcam", 35.0),
//   ("Auriculares", 60.0)
// )
// superiorDescuento: List[Double] = List(40.5, 162.0, 31.5, 54.0)
// resultadoSuperiorDescuento: Double = 288.0
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %% [markdown]
// Define una función contarVocales que reciba un String y devuelva cuántas vocales contiene (considera solo minúsculas: a, e, i, o, u).
//
// Pista: puedes usar .filter sobre los caracteres del String con .toList.
//
// Pruébala con:
//
// contarVocales("scala")     → 2
// contarVocales("big data")  → 3

// %%
def contarVocales(texto: String): Int = {
  val caracteres = texto.toList

  val contarVocales = caracteres.filter(c => c == 'a' || c == 'e' || c == 'i' || c == 'o' || c == 'u' )

  contarVocales.length
}

println(f"La palabra scala tiene ${contarVocales("scala")} vocales")
println(f"La palabra big data tiene ${contarVocales("big data")} vocales")
// Out:
// La palabra scala tiene 2 vocales
// La palabra big data tiene 3 vocales
// defined function contarVocales
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %% [markdown]
// Ejercicio P13
// Dada la siguiente lista de nombres:
//
// val nombres = List("ana", "LUIS", "Marta", "cARLOS", "elena")
// Encadena operaciones para:
//
// Convertir todos los nombres a minúsculas con .map(_.toLowerCase)
// Capitalizar la primera letra de cada uno con .map(_.capitalize)
// Ordenarlos alfabéticamente con .sorted

// %%
val nombres = List("ana", "LUIS", "Marta", "cARLOS", "elena")
val nombreMinuscula = nombres.map(_.toLowerCase)
val nombreCapitalizado = nombreMinuscula.map(_.capitalize)
val nombreOrdenado = nombreCapitalizado.sorted
println("=== Nombres ordenados alfabéticamente ===")
println(nombreOrdenado)
// Out:
// === Nombres ordenados alfabéticamente ===
// List(Ana, Carlos, Elena, Luis, Marta)
// nombres: List[String] = List("ana", "LUIS", "Marta", "cARLOS", "elena")
// nombreMinuscula: List[String] = List("ana", "luis", "marta", "carlos", "elena")
// nombreCapitalizado: List[String] = List(
//   "Ana",
//   "Luis",
//   "Marta",
//   "Carlos",
//   "Elena"
// )
// nombreOrdenado: List[String] = List("Ana", "Carlos", "Elena", "Luis", "Marta")
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %% [markdown]
// Ejercicio P14
// Define una función de orden superior aplicarDosVeces que reciba:
//
// Una función f: Int => Int
// Un número n: Int
// Y aplique f dos veces sobre n.
//
// Pruébala con:
//
// aplicarDosVeces(x => x * 3, 2)   // → 18  (2*3=6, 6*3=18)
// aplicarDosVeces(x => x + 10, 5)  // → 25  (5+10=15, 15+10=25)

// %%
def aplicarDosVeces(f: Int => Int, n: Int): Int =
  f(f(n))

aplicarDosVeces(x => x * 3, 2) // Resultado: 18
aplicarDosVeces(x => x + 10, 5) // Resultado: 25
// Out:
// defined function aplicarDosVeces
// res1_1: Int = 18
// res1_2: Int = 25

// %% [markdown]
// Dada la siguiente lista de frases:
//
// val frases = List(
//   "Scala es funcional",
//   "Big Data con Spark",
//   "Programación en la JVM",
//   "Datos y más datos",
//   "Apache Kafka y Scala"
// )
// Filtra las frases que contengan la palabra "Scala"
// Convierte cada frase filtrada a mayúsculas con .toUpperCase
// Cuenta cuántas palabras hay en total en las frases resultantes usando map(_.split(" ").length) y reduce(_ + _)
// Salida esperada:
//
// Frases con Scala: List(SCALA ES FUNCIONAL, APACHE KAFKA Y SCALA)
// Total de palabras: 7

// %%
val frases = List(
  "Scala es funcional",
  "Big Data con Spark",
  "Programación en la JVM",
  "Datos y más datos",
  "Apache Kafka y Scala"
)

//filtrar frases que contienen la palabra "Scala"
val frasesScala = frases.filter(_.contains("Scala"))
println("=== Frases que contienen 'Scala' ===")

//frases filtradas a mayúscula
val fraseFiltradaMayuscula = frasesScala.map(_.toUpperCase)
println(fraseFiltradaMayuscula)

//palabras en las frases filtradas
val resultado = fraseFiltradaMayuscula.map(_.split(" ").length).reduce(_ + _)
println("=== Número de palabras en las frases filtradas ===")
println(resultado)
// Out:
// === Frases que contienen 'Scala' ===
// List(SCALA ES FUNCIONAL, APACHE KAFKA Y SCALA)
// === Número de palabras en las frases filtradas ===
// 7
// frases: List[String] = List(
//   "Scala es funcional",
//   "Big Data con Spark",
//   "Programación en la JVM",
//   "Datos y más datos",
//   "Apache Kafka y Scala"
// )
// frasesScala: List[String] = List("Scala es funcional", "Apache Kafka y Scala")
// fraseFiltradaMayuscula: List[String] = List(
//   "SCALA ES FUNCIONAL",
//   "APACHE KAFKA Y SCALA"
// )
// resultado: Int = 7
